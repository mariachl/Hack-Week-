# %% [markdown]
# <a href="https://www.kaggle.com/code/marialchavez/global-hack-week-maria-chavez?scriptVersionId=158357901" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print('This is my Global Hack Week Submission Document')
# Out:
# This is my Global Hack Week Submission Document

# %% [markdown]
# Hello,Python

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# Write a Sorting Method

# %%
colors=('Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Purple')
colors[4:]
# Out:
# ('Blue', 'Purple')
