# %% [markdown]
# <a href="https://www.kaggle.com/code/marialchavez/global-hack-week-maria-chavez?scriptVersionId=158489430" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Hello, World

# %%
print('This is my Global Hack Week Submission Document')
# Out:
# This is my Global Hack Week Submission Document

# %% [markdown]
# Write a Sorting Method

# %%
colors=('Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Purple')
colors[0:]
# Out:
# ('Red', 'Orange', 'Yellow', 'Green', 'Blue', 'Purple')

# %%
colors[2:]
# Out:
# ('Yellow', 'Green', 'Blue', 'Purple')

# %% [markdown]
# Random Number Generator

# %%
import random

print("A random number between 0 and 5 is : ", end="")
print(random.random())

random.seed(8)

print("The mapped random number with 8 is : ", end="")
print(random.random())

random.seed(2)

print("The mapped random number with 2 is : ", end="")
print(random.random())

random.seed(4)

print("The mapped random number with 4 is : ", end="")
print(random.random())

random.seed(5)

print("The mapped random number with 5 is : ", end="")
print(random.random())
# Out:
# A random number between 0 and 5 is : 0.8219540423197268
# The mapped random number with 8 is : 0.2267058593810488
# The mapped random number with 2 is : 0.9560342718892494
# The mapped random number with 4 is : 0.23604808973743452
# The mapped random number with 5 is : 0.6229016948897019

# %% [markdown]
# Rock, Paper, Scissors Game

# %%
import random

user_action = input("Enter a choice (rock, paper, scissors): ")
possible_actions = ["rock", "paper", "scissors"]
computer_action = random.choice(possible_actions)
print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

if user_action == computer_action:
    print(f"Both players selected {user_action}. It's a tie!")
elif user_action == "rock":
    if computer_action == "scissors":
        print("Rock smashes scissors! You win!")
    else:
        print("Paper covers rock! You lose.")
elif user_action == "paper":
    if computer_action == "rock":
        print("Paper covers rock! You win!")
    else:
        print("Scissors cuts paper! You lose.")
elif user_action == "scissors":
    if computer_action == "paper":
        print("Scissors cuts paper! You win!")
    else:
        print("Rock smashes scissors! You lose.")
# Out:
# Enter a choice (rock, paper, scissors):  paper
# You chose paper, computer chose scissors.
#
# Scissors cuts paper! You lose.

# %% [markdown]
#  Hack with ChatGPT

# %%
import random

def hangman():
 words = ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape']
words = random.choice(words)
guessed_letters = []
tries = 6

while tries > 0:
 guessed_word = ""
for letter in word:
 if letter in guessed_letters:
  guessed_word += letter
else:
 guessed_word += "_"

if guessed_word == word:
 print("Congratulations! You guessed the word:", word)
break

print("Guess the word:", guessed_word)
print("Tries left:", tries)

guess = input("Enter a letter: ").lower()

if guess.isalpha() and len(guess) == 1:
    
 if guess in guessed_letters:
  print("You already guessed that letter!")
elif guess in word:
 print("Correct guess!")
guessed_letters.append(guess)
else:
 print("Wrong guess!")
  tries -= 1
guessed_letters.append(guess)
else:
 print("Invalid input. Please enter a single letter.")

if tries == 0:
 print("Game over! The word was:", word)

hangman()
# Out:
#   Cell In[43], line 33
#     else:
#     ^
# SyntaxError: invalid syntax
